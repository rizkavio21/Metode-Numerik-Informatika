# %% [markdown]
# # **Rizka Vio Octriany Inggit Sudiro**
# # **1301170121**
# # **IF41-GAB01**

# %% [markdown]
# # <center> Numerical Method for Informatics</center>
# ## <center> Finite difference method: Upwind Method in Transport Equation</center>
#
# This course is devoted to student of Undergraduate Student of Informatics, Telkom University.
#
# Detail of Course
#
#
# *   Course Name: (CSH4403) Numerical Method for Informatics
#
# *   Creator: Dr. Putu Harry Gunawan
#
#
#
# ---

# %% [markdown]
# # Exercise
#
#  Please solve the transport problem
# \begin{equation*}
#     \rho_t + b \rho_x = 0
# \end{equation*}
# and the initial density of vehicle on domain $[-1,2]$,
# \begin{equation*}
#     \rho(x,0)=\nu(x)=\begin{cases}
#     0, & \text{ if } -1 \leq x < 0\\
#     1, & \text{ if } 0 \leq x < 1\\
#     0, & \text{ otherwise}
#     \end{cases}
# \end{equation*}
#
# *   Use Upwind method for $b=1$, $N=10$ and $\Delta t=0.01$. Plot solutions at times $t=0$, $t=0.1$ and $t=1$.
# *   Repeat (a), with $b=-1$!

# %% [markdown]
# # B=1

# %%
import numpy as np
import matplotlib.pyplot as plt

def nu(xi):
  if xi >=-1 and xi<0:
    return 0
  if xi >= 0 and xi<1:
    return 1
  else:
    return 0


L1 = -1
L2 = 2
N  = 10
x = np.linspace(L1,L2,N) #for plot purpose
dx = (L2 -L1)/(N-1)
print("dx = ",dx)

Tfin = 0
#t = np.linspace(0,Tfin, T)
dt = 0.01
print("dt = ",dt)

b= 1
r= b*dt/dx #arah ke kanan
print('Courant number = ',r)

#Initial condition
rho = np.array([])
for i in range (0,N):
  rho = np.append(rho,nu(x[i]))

init = rho   # for plot purpose in initial condition

time=0
while (time<=Tfin):
  time = time + dt
  rho_n = np.array([0]) #Diriclet boundary left (diujug selalu 0)
  for i in range (1,N-1):
    rho_n = np.append(rho_n, rho[i] - r*(rho[i] - rho[i-1]))
    

  rho_n = np.append(rho_n,0)  #Diriclet boundary right
  rho = rho_n
#Endwhile


plt.grid()
plt.xlabel("x",fontsize=20)
plt.ylabel(r"$\rho(x,t)$",fontsize=20)
plt.ylim(-0.3,1.3)
plt.plot(x,init,'--', color='red', linewidth=3)
plt.plot(x,rho, color='red', linewidth=3)
plt.title("At time = {}".format(Tfin),fontsize=20)
plt.legend(['Initial', 'Upwind'],fontsize=15)
plt.show()
# Out:
# dx =  0.3333333333333333
# dt =  0.01
# Courant number =  0.030000000000000002

# %%
import numpy as np
import matplotlib.pyplot as plt

def nu(xi):
  if xi >=-1 and xi<0:
    return 0
  if xi >= 0 and xi<1:
    return 1
  else:
    return 0


L1 = -1
L2 = 2
N  = 10
x = np.linspace(L1,L2,N) #for plot purpose
dx = (L2 -L1)/(N-1)
print("dx = ",dx)

Tfin = 0.1
#t = np.linspace(0,Tfin, T)
dt = 0.01
print("dt = ",dt)

b= 1
r= b*dt/dx #arah ke kanan
print('Courant number = ',r)

#Initial condition
rho = np.array([])
for i in range (0,N):
  rho = np.append(rho,nu(x[i]))

init = rho   # for plot purpose in initial condition

time=0
while (time<=Tfin):
  time = time + dt
  rho_n = np.array([0]) #Diriclet boundary left (diujug selalu 0)
  for i in range (1,N-1):
    rho_n = np.append(rho_n, rho[i] - r*(rho[i] - rho[i-1]))
    

  rho_n = np.append(rho_n,0)  #Diriclet boundary right
  rho = rho_n
#Endwhile


plt.grid()
plt.xlabel("x",fontsize=20)
plt.ylabel(r"$\rho(x,t)$",fontsize=20)
plt.ylim(-0.3,1.3)



plt.plot(x,init,'--', color='red', linewidth=3)
plt.plot(x,rho, color='red', linewidth=3)
plt.title("At time = {}".format(Tfin),fontsize=20)
plt.legend(['Initial', 'Upwind'],fontsize=15)
plt.show()
# Out:
# dx =  0.3333333333333333
# dt =  0.01
# Courant number =  0.030000000000000002

# %%
import numpy as np
import matplotlib.pyplot as plt

def nu(xi):
  if xi >=-1 and xi<0:
    return 0
  if xi >= 0 and xi<1:
    return 1
  else:
    return 0


L1 = -1
L2 = 2
N  = 10
x = np.linspace(L1,L2,N) #for plot purpose
dx = (L2 -L1)/(N-1)
print("dx = ",dx)

Tfin = 1
#t = np.linspace(0,Tfin, T)
dt = 0.01
print("dt = ",dt)

b= 1
r= b*dt/dx #arah ke kanan
print('Courant number = ',r)

#Initial condition
rho = np.array([])
for i in range (0,N):
  rho = np.append(rho,nu(x[i]))

init = rho   # for plot purpose in initial condition

time=0
while (time<=Tfin):
  time = time + dt
  rho_n = np.array([0]) #Diriclet boundary left (diujug selalu 0)
  for i in range (1,N-1):
    rho_n = np.append(rho_n, rho[i] - r*(rho[i] - rho[i-1]))
    

  rho_n = np.append(rho_n,0)  #Diriclet boundary right
  rho = rho_n
#Endwhile


plt.grid()
plt.xlabel("x",fontsize=20)
plt.ylabel(r"$\rho(x,t)$",fontsize=20)
plt.ylim(-0.3,1.3)



plt.plot(x,init,'--', color='red', linewidth=3)
plt.plot(x,rho, color='red', linewidth=3)
plt.title("At time = {}".format(Tfin),fontsize=20)
plt.legend(['Initial', 'Upwind'],fontsize=15)
plt.show()
# Out:
# dx =  0.3333333333333333
# dt =  0.01
# Courant number =  0.030000000000000002

# %% [markdown]
# # B= -1

# %%
import numpy as np
import matplotlib.pyplot as plt

def nu(xi):
  if xi >=-1 and xi<0:
    return 0
  if xi >= 0 and xi<1:
    return 1
  else:
    return 0


L1 = -1
L2 = 2
N  = 10
x = np.linspace(L1,L2,N) #for plot purpose
dx = (L2 -L1)/(N-1)
print("dx = ",dx)


Tfin = 0
#t = np.linspace(0,Tfin, T)
dt = 0.01
print("dt = ",dt)

b=-1
r= b*dt/dx #arah ke kanan
print('Courant number = ',r)

#Initial condition
rho = np.array([])
for i in range (0,N):
  rho = np.append(rho,nu(x[i]))

init = rho   # for plot purpose in initial condition

time=0
while (time<=Tfin):
  time = time + dt
  rho_n = np.array([0]) #Diriclet boundary left (diujug selalu 0)
  for i in range (1,N-1):
    rho_n = np.append(rho_n, rho[i] - r*(rho[i] - rho[i-1]))
  rho_n = np.append(rho_n,0)  #Diriclet boundary right
  rho = rho_n
#Endwhile


plt.grid()
plt.xlabel("x",fontsize=20)
plt.ylabel(r"$\rho(x,t)$",fontsize=20)
plt.ylim(-0.3,1.3)



plt.plot(x,init,'--', color='red', linewidth=3)
plt.plot(x,rho, color='red', linewidth=3)
plt.title("At time = {}".format(Tfin),fontsize=20)
plt.legend(['Initial', 'Upwind'],fontsize=15)
plt.show()
# Out:
# dx =  0.3333333333333333
# dt =  0.01
# Courant number =  -0.030000000000000002

# %%
import numpy as np
import matplotlib.pyplot as plt

def nu(xi):
  if xi >=-1 and xi<0:
    return 0
  if xi >= 0 and xi<1:
    return 1
  else:
    return 0


L1 = -1
L2 = 2
N  = 10
x = np.linspace(L1,L2,N) #for plot purpose
dx = (L2 -L1)/(N-1)
print("dx = ",dx)


Tfin = 0.1
#t = np.linspace(0,Tfin, T)
dt = 0.01
print("dt = ",dt)

b=-1
r= b*dt/dx #arah ke kanan
print('Courant number = ',r)

#Initial condition
rho = np.array([])
for i in range (0,N):
  rho = np.append(rho,nu(x[i]))

init = rho   # for plot purpose in initial condition

time=0
while (time<=Tfin):
  time = time + dt
  rho_n = np.array([0]) #Diriclet boundary left (diujug selalu 0)
  for i in range (1,N-1):
    rho_n = np.append(rho_n, rho[i] - r*(rho[i] - rho[i-1]))
  rho_n = np.append(rho_n,0)  #Diriclet boundary right
  rho = rho_n
#Endwhile


plt.grid()
plt.xlabel("x",fontsize=20)
plt.ylabel(r"$\rho(x,t)$",fontsize=20)
plt.ylim(-0.3,1.3)



plt.plot(x,init,'--', color='red', linewidth=3)
plt.plot(x,rho, color='red', linewidth=3)
plt.title("At time = {}".format(Tfin),fontsize=20)
plt.legend(['Initial', 'Upwind'],fontsize=15)
plt.show()
# Out:
# dx =  0.3333333333333333
# dt =  0.01
# Courant number =  -0.030000000000000002

# %%
import numpy as np
import matplotlib.pyplot as plt

def nu(xi):
  if xi >=-1 and xi<0:
    return 0
  if xi >= 0 and xi<1:
    return 1
  else:
    return 0


L1 = -1
L2 = 2
N  = 10
x = np.linspace(L1,L2,N) #for plot purpose
dx = (L2 -L1)/(N-1)
print("dx = ",dx)


Tfin = 1
#t = np.linspace(0,Tfin, T)
dt = 0.01
print("dt = ",dt)

b=-1
r= b*dt/dx #arah ke kanan
print('Courant number = ',r)

#Initial condition
rho = np.array([])
for i in range (0,N):
  rho = np.append(rho,nu(x[i]))

init = rho   # for plot purpose in initial condition

time=0
while (time<=Tfin):
  time = time + dt
  rho_n = np.array([0]) #Diriclet boundary left (diujug selalu 0)
  for i in range (1,N-1):
    rho_n = np.append(rho_n, rho[i] - r*(rho[i] - rho[i-1]))
  rho_n = np.append(rho_n,0)  #Diriclet boundary right
  rho = rho_n
#Endwhile


plt.grid()
plt.xlabel("x",fontsize=20)
plt.ylabel(r"$\rho(x,t)$",fontsize=20)
plt.ylim(-0.3,1.3)



plt.plot(x,init,'--', color='red', linewidth=3)
plt.plot(x,rho, color='red', linewidth=3)
plt.title("At time = {}".format(Tfin),fontsize=20)
plt.legend(['Initial', 'Upwind'],fontsize=15)
plt.show()
# Out:
# dx =  0.3333333333333333
# dt =  0.01
# Courant number =  -0.030000000000000002
