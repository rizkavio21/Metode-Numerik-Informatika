# %% [markdown]
# # **NAMA : Rizka Vio Octriany Inggit Sudiro**
# # **1301170121**
# # **TUGAS WEEK 6**

# %% [markdown]
# # Exercise
#
# <center><img src = "https://i.imgur.com/a7Lkz1K.png" align = "center"> </center>

# %%
import numpy as np

# %% [markdown]
# # **A**

# %%
def F(X):
  f1 =  3*X[0]**2 - X[1]**2
  f2 =  3*X[0]*X[1]**2 - X[0]**3 - 1
  return np.array([f1, f2])

def g(X):
  fx= F(X)
  return fx[0]**2 + fx[1]**2

def Grad_g(X):
  fx = F(X)
  
  f1x =  2*fx[0]*6*X[0] + 2*fx[1]*3*X[1]**2 - 3*X[0]**2  
  f2x =  2*fx[0]*2*X[1] + 2*fx[1]*6*X[0]*X[1]
  
  return np.array([f1x, f2x])
def errorL2(X):
  return np.sqrt(sum(X**2))
x=[1,1]
TOL = 0.000001
N = 100

# %%
#step 1
k= 1
while (k<=N):   #step 2
  #step 3
  g1 = g(x)
  Z = Grad_g(x)
  z0 =  errorL2(Z) 
  
  #step 4
  if (z0 ==0):
    print("Zero gradient")
    print(x)
    break;
  #Step 5
  Z= Z/z0
  a1 = 0
  a3 = 1 
  g3 = g(x-a3*Z) 
  #print(g3)

  #step 6
  while(g3 >= g1):
    #step 7
    a3 = a3/2
    g3 = g(x-a3*Z)  
    #Step 8
    if a3 < TOL/2:
      print("No likely improvement")
      print(x)
      break
  #step 9
  a2 = a3/2
  g2 = g(x-a2*Z)

  #step 10
  h1 = (g2-g1)/a2
  h2 = (g3-g2)/(a3-a2)
  h3 = (h2-h1)/a3

  #step 11
  a0 = 0.5*(a2-(h1/h3)) 
  g0 = g(x-a0*Z)

  #step 12
  if (g0<g3):
    a = a0
  else:
    a = a3

  gL= g(x-a*Z)
  #Step 13
  x = x - a*Z
  print("{}, {}, {}".format(k,x,g(x)))
  #Step 14
  if abs(gL-g1) < TOL:
    print("done")
    print(x)
    break
  
  k=k+1
# Out:
# 1, [0.42883321 0.57691349], 0.4712821771433127
# 2, [0.54206797 0.79979886], 0.07265288857070797
# 3, [0.52559569 0.78896315], 0.06935470236673484
# 4, [0.54643925 0.81348499], 0.060906001307748855
# 5, [0.54276895 0.80963679], 0.06067375495806042
# No likely improvement
# [0.54276895 0.80963679]
# 6, [0.54287074 0.80974378], 0.060673577090869235
# done
# [0.54287074 0.80974378]

# %% [markdown]
# # **B**

# %%
def F(X):
  f1 =  np.log(X[0]**2+X[1]**2) - np.sin(X[0]*X[1]) - np.log(2) - np.log(np.pi)
  f2 =  np.exp(X[0] - X[1]) + np.cos(X[0]*X[1])
  return np.array([f1, f2])

def g(X):
  fx= F(X)
  return fx[0]**2 + fx[1]**2

def Grad_g(X):
  fx = F(X)
  f1x = 2*fx[0]*2*X[0] / (X[0]**2 + X[1]**2) - X[1] * np.cos(X[1]*X[0]) + 2*fx[1]*np.exp(X[0]-X[1]) - X[1] * np.sin(X[1]*X[0])
  f2x = 2*fx[0]*2*X[1] / (X[0]**2 + X[1]**2) - X[0] * np.cos(X[1]*X[0]) + 2*fx[1]*-X[0] * np.sin(X[0]*X[1]) - np.exp(X[0]-X[1]) 
  return np.array([f1x, f2x])

def errorL2(X):
  return np.sqrt(sum(X**2))
x=[2,2]
TOL = 0.000001
N = 100

#step 1
k= 1
while (k<=N):   #step 2
  #step 3
  g1 = g(x)
  Z = Grad_g(x)
  z0 =  errorL2(Z) 
  
  #step 4
  if (z0 ==0):
    print("Zero gradient")
    print(x)
    break;
  #Step 5
  Z= Z/z0
  a1 = 0
  a3 = 1 
  g3 = g(x-a3*Z) 
  #print(g3)

  #step 6
  while(g3 >= g1):
    #step 7
    a3 = a3/2
    g3 = g(x-a3*Z)  
    #Step 8
    if a3 < TOL/2:
      print("No likely improvement")
      print(x)
      break
  #step 9
  a2 = a3/2
  g2 = g(x-a2*Z)

  #step 10
  h1 = (g2-g1)/a2
  h2 = (g3-g2)/(a3-a2)
  h3 = (h2-h1)/a3

  #step 11
  a0 = 0.5*(a2-(h1/h3)) 
  g0 = g(x-a0*Z)

  #step 12
  if (g0<g3):
    a = a0
  else:
    a = a3

  gL= g(x-a*Z)
  #Step 13
  x = x - a*Z
  print("{}, {}, {}".format(k,x,g(x)))
  #Step 14
  if abs(gL-g1) < TOL:
    print("done")
    print(x)
    break
  
  k=k+1
# Out:
# 1, [1.7010668  1.84402986], 0.017752169443517058
# No likely improvement
# [1.7010668  1.84402986]
# 2, [1.70648195 1.84684688], 0.017403542212463277
# No likely improvement
# [1.70648195 1.84684688]
# 3, [1.70653149 1.84687238], 0.01740351294859485
# done
# [1.70653149 1.84687238]

# %% [markdown]
# # **C**

# %%
def F(X):
  f1 =  X[0]**3 + X[0]**2 * X[1] - X[0]*X[2] +6
  f2 =  np.exp(X[0]) + np.exp(X[1]) - X[2]
  f3 =  X[1]**2 - 2*X[1]*X[2] - 4
  return np.array([f1, f2, f3])

def g(X):
  fx= F(X)
  return fx[0]**2 + fx[1]**2 + fx[2]**2

def Grad_g(X):
  fx = F(X)

  f1x = 2*fx[0]*3*X[0]**2 + 2*X[0] * X[1] - X[2] + 2*fx[1]*np.exp(X[0]) + 2*fx[2]*-2*X[2]
  f2x = 2*fx[0]*X[0]**2 + 2*fx[1]*np.exp(X[1])+2*fx[2]*2*X[1]  
  f3x = 2*fx[0]*-X[0]+ 2*fx[1]*(1)+2*fx[2]*-2*X[2]
  return np.array([f1x, f2x, f3x])

def errorL2(X):
  return np.sqrt(sum(X**2))
x=[-1,-2,1]
TOL = 0.000001
N = 100

#step 1
k= 1
while (k<=N):   #step 2
  #step 3
  g1 = g(x)
  Z = Grad_g(x)
  z0 =  errorL2(Z) 
  
  #step 4
  if (z0 ==0):
    print("Zero gradient")
    print(x)
    break;
  #Step 5
  Z= Z/z0
  a1 = 0
  a3 = 1 
  g3 = g(x-a3*Z) 
  #print(g3)

  #step 6
  while(g3 >= g1):
    #step 7
    a3 = a3/2
    g3 = g(x-a3*Z)  
    #Step 8
    if a3 < TOL/2:
      print("No likely improvement")
      print(x)
      break
  #step 9
  a2 = a3/2
  g2 = g(x-a2*Z)

  #step 10
  h1 = (g2-g1)/a2
  h2 = (g3-g2)/(a3-a2)
  h3 = (h2-h1)/a3

  #step 11
  a0 = 0.5*(a2-(h1/h3)) 
  g0 = g(x-a0*Z)

  #step 12
  if (g0<g3):
    a = a0
  else:
    a = a3

  gL= g(x-a*Z)
  #Step 13
  x = x - a*Z
  print("{}, {}, {}".format(k,x,g(x)))
  #Step 14
  if abs(gL-g1) < TOL:
    print("done")
    print(x)
    break
  
  k=k+1
# Out:
# 1, [-1.44852192 -0.98210062  1.37931439], 9.097514277056893
# 2, [-1.68884027 -1.06060127  1.32650264], 0.7952961695043991
# 3, [-1.72120886 -1.06764662  1.32621846], 0.646916870999235
# No likely improvement
# [-1.72120886 -1.06764662  1.32621846]
# 4, [-1.71797207 -1.06803614  1.32447695], 0.645870809538888
# 5, [-1.71902373 -1.06799909  1.3248982 ], 0.6457505901093591
# No likely improvement
# [-1.71902373 -1.06799909  1.3248982 ]
# 6, [-1.71871391 -1.06801784  1.32476146], 0.6457404369867373
# 7, [-1.71880866 -1.06801283  1.3248021 ], 0.6457394803327114
# done
# [-1.71880866 -1.06801283  1.3248021 ]

# %% [markdown]
# # **D**

# %%
def F(X):
  f1 =  6*X[0] - 2 * np.cos(X[1] * X[2]) - 1
  f2 =  9*X[1] + np.sqrt(X[0]**2 + np.sin(X[2]) + 1.06) + 0.9
  f3 =  60*X[2] + 3* np.exp(-X[0]*X[1]) + 10*np.pi - 3
  return np.array([f1, f2, f3])

def g(X):
  fx= F(X)
  return fx[0]**2 + fx[1]**2 + fx[2]**2

def Grad_g(X):
  fx = F(X)

  f1x =2*fx[0]*6 + 2*fx[1]*X[0]/np.sqrt(X[0]**2+np.sin(X[2])+1.06) + 2*fx[2]*-3*X[1] * np.exp(-X[1]*X[0])
  f2x = 2*fx[0]*2*X[2] * np.sin(X[1]*X[2]) +2*fx[1]*(9) + 2*fx[2]*-3*X[0] * np.exp(-X[0]*X[1])
  f3x = 2*fx[0]*2*X[1] * np.sin(X[1]*X[2]) +2*fx[1]*0.5*np.cos(X[2])/np.sqrt(X[0]**2+np.sin(X[2])+1.06)+2*fx[2]*60
  return np.array([f1x, f2x, f3x])



def errorL2(X):
  return np.sqrt(sum(X**2))
x=[0,0,0]
TOL = 0.000001
N = 100

#step 1
k= 1
while (k<=N):   #step 2
  #step 3
  g1 = g(x)
  Z = Grad_g(x)
  z0 =  errorL2(Z) 
  
  #step 4
  if (z0 ==0):
    print("Zero gradient")
    print(x)
    break;
  #Step 5
  Z= Z/z0
  a1 = 0
  a3 = 1 
  g3 = g(x-a3*Z) 
  #print(g3)

  #step 6
  while(g3 >= g1):
    #step 7
    a3 = a3/2
    g3 = g(x-a3*Z)  
    #Step 8
    if a3 < TOL/2:
      print("No likely improvement")
      print(x)
      break
  #step 9
  a2 = a3/2
  g2 = g(x-a2*Z)

  #step 10
  h1 = (g2-g1)/a2
  h2 = (g3-g2)/(a3-a2)
  h3 = (h2-h1)/a3

  #step 11
  a0 = 0.5*(a2-(h1/h3)) 
  g0 = g(x-a0*Z)

  #step 12
  if (g0<g3):
    a = a0
  else:
    a = a3

  gL= g(x-a*Z)
  #Step 13
  x = x - a*Z
  print("{}, {}, {}".format(k,x,g(x)))
  #Step 14
  if abs(gL-g1) < TOL:
    print("done")
    print(x)
    break
  
  k=k+1
# Out:
# 1, [ 0.00500072 -0.0048246  -0.52393467], 11.396405631778984
# 2, [ 0.32822486 -0.26709105 -0.51892192], 1.799754936747469
# 3, [ 0.32996303 -0.26512946 -0.52872754], 1.4526111616316795
# 4, [ 0.35170369 -0.24493714 -0.52083531], 1.1795810657599486
# 5, [ 0.35321543 -0.24355119 -0.52853511], 0.9656117315788508
# 6, [ 0.37214281 -0.22935332 -0.52226479], 0.7947797659304774
# 7, [ 0.37344914 -0.22838065 -0.52841066], 0.6585462447454902
# 8, [ 0.38988757 -0.21853236 -0.52335792], 0.5481731554115082
# 9, [ 0.39101149 -0.21785387 -0.52834101], 0.45867801749683973
# 10, [ 0.40525058 -0.21113216 -0.52421443], 0.3851531273244617
# 11, [ 0.40621469 -0.2106613  -0.52831278], 0.32466329200898386
# 12, [ 0.41849905 -0.20616661 -0.52490683], 0.2743813856977453
# 13, [ 0.41932482 -0.205841   -0.52831429], 0.2325996901820875
# 14, [ 0.42988506 -0.20290621 -0.52547459], 0.1975419800051821
# 15, [ 0.43059171 -0.20268146 -0.52833505], 0.16811855269472217
# 16, [ 0.43965654 -0.20081761 -0.52594924], 0.14325630496166947
# 17, [ 0.440261   -0.2006626  -0.52836748], 0.12224048095348547
# 18, [ 0.44803348 -0.19952369 -0.52635169], 0.1043948770666662
# 19, [ 0.4485505  -0.19941676 -0.52840603], 0.08923628692338759
# 20, [ 0.45520894 -0.19876107 -0.5266962 ], 0.07632109721321195
# 21, [ 0.45565125 -0.19868724 -0.52844689], 0.06531744977568633
# 22, [ 0.46135245 -0.19834779 -0.52699219], 0.05592110343295447
# 23, [ 0.46173094 -0.19829671 -0.52848748], 0.04789675918782744
# 24, [ 0.46661244 -0.19815958 -0.52724718], 0.041034022716881974
# 25, [ 0.46693644 -0.19812416 -0.52852624], 0.035164475347804786
# 26, [ 0.47111644 -0.19811271 -0.52746712], 0.030139514681010428
# 27, [ 0.47139386 -0.19808806 -0.52856228], 0.025837575731334158
# 28, [ 0.47497383 -0.19815132 -0.52765682], 0.022152165041521454
# 29, [ 0.47521146 -0.1981341  -0.52859515], 0.018994782308910173
# 30, [ 0.47827817 -0.19823862 -0.52782044], 0.016288712005927224
# 31, [ 0.47848176 -0.19822653 -0.52862472], 0.013969365042596894
# 32, [ 0.48110929 -0.19835075 -0.52796148], 0.011980935644102176
# 33, [ 0.48128376 -0.19834221 -0.52865106], 0.010276197155695327
# 34, [ 0.48353543 -0.19847252 -0.52808298], 0.008814374961311652
# 35, [ 0.48368498 -0.19846645 -0.52867433], 0.007560877481418304
# 36, [ 0.48561485 -0.19859458 -0.52818759], 0.006485832502983364
# 37, [ 0.48574306 -0.19859023 -0.52869477], 0.005563870569901332
# 38, [ 0.48739747 -0.19871139 -0.52827758], 0.004773072516626033
# 39, [ 0.4875074  -0.19870824 -0.52871263], 0.004094758372940106
# 40, [ 0.48892591 -0.19881992 -0.52835499], 0.0035129026443375387
# 41, [ 0.48902018 -0.19881763 -0.52872818], 0.0030137835743514444
# 42, [ 0.49023654 -0.19891876 -0.52842154], 0.002585615855815192
# 43, [ 0.49031739 -0.19891707 -0.52874169], 0.0022183160423684227
# 44, [ 0.49136051 -0.19900751 -0.52847874], 0.0019032141562944091
# 45, [ 0.49142986 -0.19900625 -0.52875339], 0.0016328975796889081
# 46, [ 0.49232451 -0.19908638 -0.52852787], 0.0014009872112815697
# 47, [ 0.492384   -0.19908542 -0.52876351], 0.0012020215362257565
# 48, [ 0.49315139 -0.19915592 -0.52857008], 0.001031320346828133
# 49, [ 0.49320241 -0.19915519 -0.52877225], 0.0008848668382892168
# 50, [ 0.49386068 -0.19921688 -0.52860633], 0.0007592153372811847
# 51, [ 0.49390445 -0.19921631 -0.52877978], 0.0006514111022371212
# 52, [ 0.49446912 -0.19927008 -0.52863746], 0.0005589173954613114
# 53, [ 0.49450668 -0.19926964 -0.52878628], 0.0004795603913237775
# 54, [ 0.49499109 -0.19931635 -0.52866418], 0.00041147259933389937
# 55, [ 0.49502331 -0.199316   -0.52879187], 0.0003530544901720517
# 56, [ 0.49543889 -0.19935647 -0.52868712], 0.0003029313375223993
# 57, [ 0.49546653 -0.19935619 -0.52879668], 0.0002599249120126014
# 58, [ 0.49582308 -0.1993912  -0.52870681], 0.00022302472055075068
# 59, [ 0.49584679 -0.19939097 -0.52880081], 0.00019136367912554037
# 60, [ 0.49615269 -0.1994212  -0.52872371], 0.0001641977537866326
# 61, [ 0.49617304 -0.19942101 -0.52880437], 0.0001408887885974866
# 62, [ 0.49643549 -0.19944709 -0.52873822], 0.00012088897011123409
# 63, [ 0.49645295 -0.19944693 -0.52880743], 0.000103728595761414
# 64, [ 0.49667813 -0.1994694  -0.52875067], 8.900434184030159e-05
# 65, [ 0.49669311 -0.19946927 -0.52881005], 7.637028558055881e-05
# 66, [ 0.49688632 -0.19948861 -0.52876135], 6.552973102006485e-05
# 67, [ 0.49689917 -0.19948851 -0.52881231], 5.622804703028108e-05
# 68, [ 0.49706494 -0.19950515 -0.52877052], 4.824677097198829e-05
# 69, [ 0.49707597 -0.19950506 -0.52881424], 4.139846430902248e-05
# 70, [ 0.49721821 -0.19951937 -0.52877839], 3.552227387019505e-05
# 71, [ 0.49722767 -0.19951929 -0.5288159 ], 3.048021737200691e-05
# 72, [ 0.49734972 -0.19953159 -0.52878514], 2.6153862284252537e-05
# 73, [ 0.49735784 -0.19953153 -0.52881733], 2.2441629894250397e-05
# 74, [ 0.49746256 -0.1995421  -0.52879094], 1.925632306696428e-05
# 75, [ 0.49746952 -0.19954205 -0.52881856], 1.6523141463495958e-05
# 76, [ 0.49755938 -0.19955113 -0.52879591], 1.4177910289450629e-05
# 77, [ 0.49756536 -0.19955108 -0.52881961], 1.216556178244381e-05
# 78, [ 0.49764246 -0.19955888 -0.52880018], 1.0438844060307295e-05
# 79, [ 0.49764758 -0.19955884 -0.52882051], 8.957215588388476e-06
# 80, [ 0.49771374 -0.19956554 -0.52880384], 7.685885309378197e-06
# 81, [ 0.49771814 -0.19956551 -0.52882129], 6.595005544152716e-06
# 82, [ 0.49777491 -0.19957126 -0.52880698], 5.658960331203391e-06
# done
# [ 0.49777491 -0.19957126 -0.52880698]
